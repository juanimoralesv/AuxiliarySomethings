# %% [markdown]
# Here I will try to scrape the Wikipedia page for the Ariane 5 rocket, to get the table with the whole list of its launches.

# %%
# import what's apparently needed
import pandas as pd
import numpy as np

# %%
# where we are getting the table:
a5url = 'https://en.wikipedia.org/wiki/Ariane_5'

# %%
# read the Ariane 5 page and get the tables into a list of tables (apparently):
a5tables = pd.read_html(a5url)

# %%
# check which table is the one of interest
a5tables[2].head()
# Out:
#    # Flight no.        DateTime (UTC) Rocket typeSerial no.  \
# 0  1   V-88[69]      4 June 199612:34                  G501
# 1  1   V-88[69]                   NaN                   NaN
# 2  2      V-101  30 October 199713:43                  G502
# 3  2      V-101                   NaN                   NaN
# 4  3      V-112  21 October 199816:37                  G503
#
#                             Payload  \
# 0                           Cluster
# 1                               NaN
# 2  MaqSat-H, TEAMSAT, MaqSat-B, YES
# 3                               NaN
# 4                     MaqSat 3, ARD
#
#   Total payload mass (including launch adapters and SYLDA) Orbit Customers  \
# 0                                                NaN         NaN       NaN
# 1                                                NaN         NaN       NaN
# 2                                                NaN         NaN       NaN
# 3                                                NaN         NaN       NaN
# 4                                          ~6,800 kg         GTO       NaN
#
#          Launchoutcome
# 0              Failure
# 1                  NaN
# 2  Partial failure[70]
# 3                  NaN
# 4              Success

# %%
# extract the desired table from the list of them
a5lt = a5tables[2]

# %%
a5lt
# Out:
#        # Flight no.         DateTime (UTC) Rocket typeSerial no.  \
# 0      1   V-88[69]       4 June 199612:34                  G501
# 1      1   V-88[69]                    NaN                   NaN
# 2      2      V-101   30 October 199713:43                  G502
# 3      2      V-101                    NaN                   NaN
# 4      3      V-112   21 October 199816:37                  G503
# ..   ...        ...                    ...                   ...
# 207  108     VA-252  18 February 202022:18               ECA5111
# 208  109     VA-253    15 August 202022:04               ECA5112
# 209  110     VA-254      30 July 202121:00               ECA5113
# 210  111     VA-255   24 October 202102:10               ECA5115
# 211  112     VA-256  25 December 202112:20               ECA5114
#
#                               Payload  \
# 0                             Cluster
# 1                                 NaN
# 2    MaqSat-H, TEAMSAT, MaqSat-B, YES
# 3                                 NaN
# 4                       MaqSat 3, ARD
# ..                                ...
# 207            JCSAT-17GEO-KOMPSAT 2B
# 208             Galaxy 30MEV-2BSAT-4b
# 209       Eutelsat QuantumStar One D2
# 210                 SES-17Syracuse 4A
# 211        James Webb Space Telescope
#
#     Total payload mass (including launch adapters and SYLDA)         Orbit  \
# 0                                                  NaN                 NaN
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                            ~6,800 kg                 GTO
# ..                                                 ...                 ...
# 207                                           9,236 kg                 GTO
# 208  10,468 kg[106]including 765 kg of support stru...                 GTO
# 209                                          10,515 kg                 GTO
# 210                                     11,210 kg[107]                 GTO
# 211                             6,161.4 kg (13,584 lb)        Sun–Earth L2
#
#                          Customers        Launchoutcome
# 0                              NaN              Failure
# 1                              NaN                  NaN
# 2                              NaN  Partial failure[70]
# 3                              NaN                  NaN
# 4                              NaN              Success
# ..                             ...                  ...
# 207           SKY Perfect JSATKARI              Success
# 208  IntelsatNorthrop GrummanB-SAT              Success
# 209               EutelsatStar One              Success
# 210                    SES S.A.DGA              Success
# 211       NASA / ESA / CSA / STScI              Success
#
# [212 rows x 9 columns]

# %%
# rename columns with shorter names
a5lt.rename(columns={'Flight no.': 'flight', 'DateTime (UTC)': 'date', 'Rocket typeSerial no.': 'serial', 'Total payload mass (including launch adapters and SYLDA)': 'mass'}, inplace=True)

# %%
# rename columns with shorter names
a5lt.rename(columns={'Payload': 'payload', 'Orbit': 'orbit', 'Customers': 'customers', 'Launchoutcome': 'outcome'}, inplace=True)

# %%
a5lt
# Out:
#        #    flight                   date   serial  \
# 0      1  V-88[69]       4 June 199612:34     G501
# 1      1  V-88[69]                    NaN      NaN
# 2      2     V-101   30 October 199713:43     G502
# 3      2     V-101                    NaN      NaN
# 4      3     V-112   21 October 199816:37     G503
# ..   ...       ...                    ...      ...
# 207  108    VA-252  18 February 202022:18  ECA5111
# 208  109    VA-253    15 August 202022:04  ECA5112
# 209  110    VA-254      30 July 202121:00  ECA5113
# 210  111    VA-255   24 October 202102:10  ECA5115
# 211  112    VA-256  25 December 202112:20  ECA5114
#
#                               payload  \
# 0                             Cluster
# 1                                 NaN
# 2    MaqSat-H, TEAMSAT, MaqSat-B, YES
# 3                                 NaN
# 4                       MaqSat 3, ARD
# ..                                ...
# 207            JCSAT-17GEO-KOMPSAT 2B
# 208             Galaxy 30MEV-2BSAT-4b
# 209       Eutelsat QuantumStar One D2
# 210                 SES-17Syracuse 4A
# 211        James Webb Space Telescope
#
#                                                   mass         orbit  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                            ~6,800 kg           GTO
# ..                                                 ...           ...
# 207                                           9,236 kg           GTO
# 208  10,468 kg[106]including 765 kg of support stru...           GTO
# 209                                          10,515 kg           GTO
# 210                                     11,210 kg[107]           GTO
# 211                             6,161.4 kg (13,584 lb)  Sun–Earth L2
#
#                          customers              outcome
# 0                              NaN              Failure
# 1                              NaN                  NaN
# 2                              NaN  Partial failure[70]
# 3                              NaN                  NaN
# 4                              NaN              Success
# ..                             ...                  ...
# 207           SKY Perfect JSATKARI              Success
# 208  IntelsatNorthrop GrummanB-SAT              Success
# 209               EutelsatStar One              Success
# 210                    SES S.A.DGA              Success
# 211       NASA / ESA / CSA / STScI              Success
#
# [212 rows x 9 columns]

# %%
# drop duplicate rows that appear when there's a row partilly divided in the vertical direction (a part of the row becomes two)
a5lt.drop_duplicates(subset=['date', 'serial', 'payload'], keep=False, inplace = True)

# %%
a5lt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132 entries, 0 to 211
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          132 non-null    int64
#  1   flight     132 non-null    object
#  2   date       132 non-null    object
#  3   serial     132 non-null    object
#  4   payload    132 non-null    object
#  5   mass       128 non-null    object
#  6   orbit      130 non-null    object
#  7   customers  83 non-null     object
#  8   outcome    132 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 10.3+ KB

# %%
a5lt["notes"] = np.nan

# %%
a5lt.head()
# Out:
#    #    flight                    date serial  \
# 0  1  V-88[69]        4 June 199612:34   G501
# 2  2     V-101    30 October 199713:43   G502
# 4  3     V-112    21 October 199816:37   G503
# 6  4     V-119   10 December 199914:32   G504
# 8  5     V-128  21 March 200023:28[71]   G505
#
#                             payload       mass orbit customers  \
# 0                           Cluster        NaN   NaN       NaN
# 2  MaqSat-H, TEAMSAT, MaqSat-B, YES        NaN   NaN       NaN
# 4                     MaqSat 3, ARD  ~6,800 kg   GTO       NaN
# 6                        XMM-Newton   3,800 kg   HEO       NaN
# 8                  INSAT-3BAsiaStar  ~5,800 kg   GTO       NaN
#
#                outcome  notes
# 0              Failure    NaN
# 2  Partial failure[70]    NaN
# 4              Success    NaN
# 6              Success    NaN
# 8              Success    NaN

# %%
# this is 'a bit' crappy, because of the drop method changing the ammount of indeces
# there will come a day when I improve this, but it is not this day
for i in range(0, a5lt.shape[0]):
    if a5lt.iloc[i, 2] == a5lt.iloc[i, 3] == a5lt.iloc[i, 4]:
        a5lt.iloc[i-1, 9] = a5lt.iloc[i, 2]
        a5lt.drop(a5lt.index[i], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-a759cc7f7ced> in <module>
#       2 # there will come a day when I improve this, but it is not this day
#       3 for i in range(0, a5lt.shape[0]):
# ----> 4     if a5lt.iloc[i, 2] == a5lt.iloc[i, 3] == a5lt.iloc[i, 4]:
#       5         a5lt.iloc[i-1, 9] = a5lt.iloc[i, 2]
#       6         a5lt.drop(a5lt.index[i], inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1448     def _getitem_tuple(self, tup: Tuple):
#    1449
# -> 1450         self._has_valid_tuple(tup)
#    1451         with suppress(IndexingError):
#    1452             return self._getitem_lowerdim(tup)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     721         for i, k in enumerate(key):
#     722             try:
# --> 723                 self._validate_key(k, i)
#     724             except ValueError as err:
#     725                 raise ValueError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1356             return
#    1357         elif is_integer(key):
# -> 1358             self._validate_integer(key, axis)
#    1359         elif isinstance(key, tuple):
#    1360             # a tuple should already have been caught by this point
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
# cast every field into strings
a5lt = a5lt.astype(str)

# %%
a5lt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 0 to 211
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          112 non-null    object
#  1   flight     112 non-null    object
#  2   date       112 non-null    object
#  3   serial     112 non-null    object
#  4   payload    112 non-null    object
#  5   mass       112 non-null    object
#  6   orbit      112 non-null    object
#  7   customers  112 non-null    object
#  8   outcome    112 non-null    object
#  9   notes      112 non-null    object
# dtypes: object(10)
# memory usage: 9.6+ KB

# %% [markdown]
# But it still shows the data type as object...

# %%
# remove all citations:
for i in range(0, a5lt.shape[1]):
    a5lt.iloc[:,i] = a5lt.iloc[:,i].str.replace(r"\[.*?\]","")
# Out:
# <ipython-input-17-1a961a4df342>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   a5lt.iloc[:,i] = a5lt.iloc[:,i].str.replace(r"\[.*?\]","")

# %% [markdown]
# Right now regex means nothing to me, but I guess I will have to checks what this is

# %%
# remove all nans:
for i in range(0, a5lt.shape[1]):
    a5lt.iloc[:,i] = a5lt.iloc[:,i].str.replace(r"nan","")

# %%
a5lt
# Out:
#        #  flight                   date   serial  \
# 0      1    V-88       4 June 199612:34     G501
# 2      2   V-101   30 October 199713:43     G502
# 4      3   V-112   21 October 199816:37     G503
# 6      4   V-119  10 December 199914:32     G504
# 8      5   V-128     21 March 200023:28     G505
# ..   ...     ...                    ...      ...
# 207  108  VA-252  18 February 202022:18  ECA5111
# 208  109  VA-253    15 August 202022:04  ECA5112
# 209  110  VA-254      30 July 202121:00  ECA5113
# 210  111  VA-255   24 October 202102:10  ECA5115
# 211  112  VA-256  25 December 202112:20  ECA5114
#
#                               payload  \
# 0                             Cluster
# 2    MaqSat-H, TEAMSAT, MaqSat-B, YES
# 4                       MaqSat 3, ARD
# 6                          XMM-Newton
# 8                    INSAT-3BAsiaStar
# ..                                ...
# 207            JCSAT-17GEO-KOMPSAT 2B
# 208             Galaxy 30MEV-2BSAT-4b
# 209       Eutelsat QuantumStar One D2
# 210                 SES-17Syracuse 4A
# 211        James Webb Space Telescope
#
#                                                  mass         orbit  \
# 0
# 2
# 4                                           ~6,800 kg           GTO
# 6                                            3,800 kg           HEO
# 8                                           ~5,800 kg           GTO
# ..                                                ...           ...
# 207                                          9,236 kg           GTO
# 208  10,468 kgincluding 765 kg of support structures.           GTO
# 209                                         10,515 kg           GTO
# 210                                         11,210 kg           GTO
# 211                            6,161.4 kg (13,584 lb)  Sun–Earth L2
#
#                          customers          outcome notes
# 0                                           Failure
# 2                                   Partial failure
# 4                                           Success
# 6                                           Success
# 8                                           Success
# ..                             ...              ...   ...
# 207           SKY Perfect JSATKARI          Success
# 208  IntelsatNorthrop GrummanB-SAT          Success
# 209               EutelsatStar One          Success
# 210                    SES S.A.DGA          Success
# 211       NASA / ESA / CSA / STScI          Success
#
# [112 rows x 10 columns]

# %%
# Re-arrange date/time
for i in range(0, a5lt.shape[0]):
    tempsplit = a5lt.iloc[i, 2].split()
    a5lt.iloc[i, 2] = tempsplit[1]+' '+tempsplit[0]+', '+tempsplit[2][0:4]+' || '+tempsplit[2][4:]

# %%
a5lt.head()
# Out:
#    # flight                        date serial  \
# 0  1   V-88       June 4, 1996 || 12:34   G501
# 2  2  V-101   October 30, 1997 || 13:43   G502
# 4  3  V-112   October 21, 1998 || 16:37   G503
# 6  4  V-119  December 10, 1999 || 14:32   G504
# 8  5  V-128     March 21, 2000 || 23:28   G505
#
#                             payload       mass orbit customers  \
# 0                           Cluster
# 2  MaqSat-H, TEAMSAT, MaqSat-B, YES
# 4                     MaqSat 3, ARD  ~6,800 kg   GTO
# 6                        XMM-Newton   3,800 kg   HEO
# 8                  INSAT-3BAsiaStar  ~5,800 kg   GTO
#
#            outcome notes
# 0          Failure
# 2  Partial failure
# 4          Success
# 6          Success
# 8          Success

# %% [markdown]
# ### Save as CSV

# %%
a5lt.to_csv('ariane5LaunchTable.csv', index = False)

# %% [markdown]
# ### Now to get the HTML code needed for the RR

# %%
# create table html code
this_table_name = 'Ariane 5 Full Launch Table'
with open(f'{this_table_name}.txt', 'w') as f:
    f.write('')

# %%
# open figure tab and table tab
with open(f'{this_table_name}.txt', 'a') as f:
    f.write('<figure class="wp-block-table">')
    f.write('\n	<table>')

# %%
# create header from DF header
# open header tag:
with open(f'{this_table_name}.txt', 'a') as f:
    f.write('\n		<thead>')
# open row tag:
    f.write('\n			<tr>')
# create each header row element
for cheader in [*a5lt]:
    with open(f'{this_table_name}.txt', 'a') as f:
        f.write(f'\n				<th>{cheader}</th>')
# close row tag:
with open(f'{this_table_name}.txt', 'a') as f:
    f.write('\n			</tr>')
# close header tag:
    f.write('\n		</thead>')

# %%
# create body from DF rows
# open body tag:
with open(f'{this_table_name}.txt', 'a') as f:
    f.write('\n		<tbody>')

for i in range(0, a5lt.shape[0]):
# open row tag:
    with open(f'{this_table_name}.txt', 'a') as f:
        f.write('\n			<tr>')
# create each body row element
    for relement in [*a5lt.iloc[i, :]]:
        with open(f'{this_table_name}.txt', 'a') as f:
            f.write(f'\n				<td>{relement}</td>')
# close row tag:
    with open(f'{this_table_name}.txt', 'a') as f:
        f.write('\n			</tr>')

# close body tag:
with open(f'{this_table_name}.txt', 'a') as f:
    f.write('\n		</tbody>')

# %%
# close table tab and figure tab
with open(f'{this_table_name}.txt', 'a') as f:
    f.write('\n	</table>')
    f.write('\n</figure>')
